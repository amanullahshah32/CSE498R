# %% [markdown]
# <a href="https://colab.research.google.com/github/amanullahshah32/CSE498R/blob/main/Sentiment%20Analysis/Practice/Sentiment_Analysis_using_ROBERTA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google_play_scraper # scraping reviews
# !pip install -1 transformers # sentiment
# !pip install -q plotly-express # Data visualization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -1

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, reviews_all
import plotly.express as px

# %%
from google_play_scraper import reviews_all, Sort

# Fetch all reviews, sorted by newest
doc_time_project = reviews_all(
    'com.media365ltd.doctime',  # App package name
    sleep_milliseconds=100,
    lang='en',
    sort=Sort.NEWEST  # Correct sorting option
)

# %%
# doc_time_project

# %%
df = pd.json_normalize(doc_time_project)

# %%
df
# Out:
#                                   reviewId       userName  \
# 0     ec42058f-2b9c-492d-8f1f-0c01879edd60  A Google user
# 1     72b98bba-d2a7-4333-91a6-1e23bcdf1e0e  A Google user
# 2     48ea9e49-44c9-4160-96c2-667cf6441df8  A Google user
# 3     b73ce661-4ff6-46e8-bda0-bfce7ca0edb9  A Google user
# 4     32e487f3-086c-42b0-b08c-ac80ac7d05be  A Google user
# ...                                    ...            ...
# 3810  b99e0e2a-6298-4ba5-8702-3247d8554c13  A Google user
# 3811  9a9e8d2a-7fa3-446e-bd57-b1ce98b511db  A Google user
# 3812  65d04e9a-d424-4d5d-abcb-e1b027789e67  A Google user
# 3813  88914d39-420c-491e-9a30-e8685cd64ce1  A Google user
# 3814  2686f079-d82e-4fea-92cf-168c9f5999ac  A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
df['score'].mean()
# Out:
# 4.4859764089121885

# %%
df['reviewCreatedVersion'].value_counts()
# Out:
# reviewCreatedVersion
# 0.11.18    153
# 0.9.10     112
# 0.11.25    101
# 0.8.1       91
# 0.10.7      87
#           ...
# 0.17.14      1
# 0.18.5       1
# 0.25.9       1
# 0.10.8       1
# 0.25.23      1
# Name: count, Length: 204, dtype: int64

# %%
from transformers import pipeline

sentiment_analysis = pipeline('sentiment-analysis', model = 'siebert/sentiment-roberta-large-english')
# Out:
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning:
#
# `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884

# %%
from transformers import AutoTokenizer, pipeline

# Load the sentiment analysis model and tokenizer
sentiment_analysis = pipeline("sentiment-analysis", model="siebert/sentiment-roberta-large-english")
tokenizer = AutoTokenizer.from_pretrained("siebert/sentiment-roberta-large-english")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning:
#
# `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884

# %%
print(sentiment_analysis("Best consultation app i have ever used. "))
# Out:
# [{'label': 'POSITIVE', 'score': 0.998684823513031}]

# %%
df.dtypes
# Out:
# reviewId                        object
# userName                        object
# userImage                       object
# content                         object
# score                            int64
# thumbsUpCount                    int64
# reviewCreatedVersion            object
# at                      datetime64[ns]
# replyContent                    object
# repliedAt               datetime64[ns]
# appVersion                      object
# dtype: object

# %%
df['content'] = df['content'].astype(str)

# %%
# Check the data types and sample values in the content column
print(df['content'].dtype)
print(df['content'].sample(10))  # Show 10 random samples from the content
print(df['content'].apply(type).value_counts())  # Count the types present in the column
# Out:
# object
# 3697                                                 nice
# 2493                                             Good app
# 2585                                               Awsome
# 2347    Best app. Using the app, I've been taken presc...
# 1884                                  Very helpful apps 🥰
# 3022                                             Best app
# 1942    Khub valo guied korsay .excellent doctor are v...
# 3644    This is a really great app for consulting doctors
# 3028    All is well but it would be so good if old pre...
# 2646    Excellent apps i have ever seen. Very much eas...
# Name: content, dtype: object
# content
# <class 'str'>    3815
# Name: count, dtype: int64

# %%
from transformers import AutoTokenizer, pipeline

# Load the sentiment analysis model and tokenizer
sentiment_analysis = pipeline("sentiment-analysis", model="siebert/sentiment-roberta-large-english")
tokenizer = AutoTokenizer.from_pretrained("siebert/sentiment-roberta-large-english")

# Define a function to handle tokenization and truncation
def analyze_sentiment(text):
    if isinstance(text, str) and text.strip():  # Check if text is a non-empty string
        # Tokenize the input text and truncate to 512 tokens
        tokens = tokenizer(text, truncation=True, max_length=512, padding='max_length', return_tensors='pt')
        # Perform sentiment analysis on the tokenized input
        outputs = sentiment_analysis(tokens['input_ids'][0], return_all_scores=False)
        return outputs[0]['label']
    else:
        return "Invalid content"  # Handle non-string or empty cases

# Apply the sentiment analysis function to each row
df['result'] = df['content'].apply(analyze_sentiment)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning:
#
# `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning:
#
# `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-0af91ca41e56> in <cell line: 19>()
#      17
#      18 # Apply the sentiment analysis function to each row
# ...

# %%
import pandas as pd
from transformers import AutoTokenizer, pipeline

# Load the sentiment analysis model and tokenizer
sentiment_analysis = pipeline("sentiment-analysis", model="siebert/sentiment-roberta-large-english")
tokenizer = AutoTokenizer.from_pretrained("siebert/sentiment-roberta-large-english")

# Define a function to handle tokenization and truncation
def analyze_sentiment(text):
    if isinstance(text, str) and text.strip():  # Check if text is a non-empty string
        try:
            # Tokenize the input text and truncate to 512 tokens
            tokens = tokenizer(text, truncation=True, max_length=512, padding='max_length', return_tensors='pt')
            # Perform sentiment analysis on the tokenized input
            outputs = sentiment_analysis(tokens['input_ids'][0], top_k=1)  # Use top_k instead of return_all_scores
            return outputs[0]['label']
        except Exception as e:
            print(f"Error processing text: {text[:50]}... | Error: {e}")
            return "Processing Error"  # Return a generic error message
    else:
        print(f"Invalid input detected: {text} (type: {type(text)})")  # Log invalid entries
        return "Invalid content"

# Sample DataFrame for testing
# Replace this with your actual DataFrame
# df = pd.DataFrame({'content': ["This is great!", None, ""]})

# Apply the sentiment analysis function to each row
df['result'] = df['content'].apply(analyze_sentiment)

# Display the result
# print(df[['content', 'result']])
# Out:
# Error processing text: well... | Error: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# Error processing text: khub valo... | Error: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# Error processing text: Amazing app Dr's are very careful really exception... | Error: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# Error processing text: ভালো... | Error: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# ...

# %%
df[['content', 'result']]
# Out:
#                                                 content            result
# 0                                                  well  Processing Error
# 1                                             khub valo  Processing Error
# 2     Amazing app Dr's are very careful really excep...  Processing Error
# 3                                                  ভালো  Processing Error
# 4                                                  ভালো  Processing Error
# ...                                                 ...               ...
# 3810  Doctime is very helpful and good service from ...  Processing Error
# 3811  Best consultation app i have ever used. great ...  Processing Error
# 3812  আমি প্রথমেই ধন্যবাদ জানাই DocTime কোম্পানিকে, ...  Processing Error
# 3813  Really awesome this app. DocTime application i...  Processing Error
# 3814                                      Important app  Processing Error
#
# [3815 rows x 2 columns]

# %%
# %%time

from transformers import AutoTokenizer, pipeline

# Load the sentiment analysis model and tokenizer
sentiment_analysis = pipeline("sentiment-analysis", model="siebert/sentiment-roberta-large-english")
tokenizer = AutoTokenizer.from_pretrained("siebert/sentiment-roberta-large-english")

# Define a function to handle tokenization and truncation
def analyze_sentiment(text):
    if isinstance(text, str) and text:  # Check if text is a non-empty string
        # Tokenize the input text and truncate to 512 tokens
        tokens = tokenizer(text, truncation=True, max_length=512, padding='max_length', return_tensors='pt')
        # Perform sentiment analysis on the tokenized input
        outputs = sentiment_analysis(tokens['input_ids'][0], return_all_scores=False)
        return outputs[0]['label']
    else:
        return "No content"  # Handle non-string or empty cases

# Apply the sentiment analysis function to each row
df['result'] = df['content'].apply(analyze_sentiment)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning:
#
# `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning:
#
# `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
# ...

# %%
# Truncate text to the first 512 characters (or tokens) if it's too long
df['result'] = df['content'].apply(lambda x: sentiment_analysis(x[:512])[0]['label'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-69d26b5c7687> in <cell line: 2>()
#       1 # Truncate text to the first 512 characters (or tokens) if it's too long
# ----> 2 df['result'] = df['content'].apply(lambda x: sentiment_analysis(x[:512])[0]['label'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
df['result'] = df['content'].apply(lambda x: sentiment_analysis())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-74c068d56c99> in <cell line: 1>()
# ----> 1 df['result'] = df['content'].apply(lambda x: sentiment_analysis())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# ...
